# %%
import numpy as np
import zarr
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

RUNTIME = 1800 #seconds
root = zarr.open("/home/anthony/papers/aamas2024/sim_results/rtbr89cz_attrition_run1.zarr", mode="r")
# test = zarr.open("../../results_GOOD.zarr", mode="r")
# test = zarr.open("/home/anthony/idev/patrolling_sim/results.zarr", mode="r")
root.tree()
# print([i/1.0e9 for i in root["cumberland_6"]["AHPA"]["run_3"]["runtime_requested"]])
# Out:
# Tree(nodes=(Node(disabled=True, name='/', nodes=(Node(disabled=True, name='cumberland_6', nodes=(Node(disabled…

# %%
def analyzeRun(run: zarr.hierarchy):
    # print(f"Analyze {run.name}")

    numNodes = run["graph"].shape[0]
    numAgents = run["origins"].shape[0]

    times = np.array(run["visits"]["time_ns"]) / 1.0e9 #seconds to ns
    data = np.transpose(np.vstack([times, run["visits"]["agent"], run["visits"]["node"]]))
    # print(data.shape)
    # print(data[np.where(data[:,2] == 5)])

    # print(f"Attrition times: {[(i/1.0e9, j) for i,j in run['attrition_times']]}")

    idleness = np.ndarray((RUNTIME + 1, numNodes + 1))
    idleness[:,0] = range(RUNTIME + 1)
    for i in range(numNodes):
        nodeVisits = data[np.where(data[:,2] == i)]

        # Add beginning and end.
        nodeVisits = np.append([[0, 0, i]], nodeVisits, axis=0)
        nodeVisits = np.append(nodeVisits, [[RUNTIME, 0, i]], axis=0)

        # nodeIdleness = []
        idl = 0.0
        visitIdx = 0

        for t in range(RUNTIME + 1):
            if visitIdx + 1 < nodeVisits.shape[0] and t > nodeVisits[visitIdx + 1][0]:
                visitIdx += 1
            idl = t - nodeVisits[visitIdx][0] 
            idleness[t][i + 1] = idl
    
    messages = np.ndarray((RUNTIME + 1, 1))
    commTimes = np.array(run["comm_times"]) / 1.0e9
    for i in range(RUNTIME + 1):
        messages[i] = np.count_nonzero(commTimes < i)

    return idleness, messages

def analyzeAlg(alg):
    idleness = np.ndarray((RUNTIME + 1, 1))
    idleness[:,0] = range(RUNTIME + 1)
    messages = np.ndarray((RUNTIME + 1, 1))
    messages[:,0] = range(RUNTIME + 1)
    for run in alg:
        try:
            # Check if run has runtime greater than or equal to requested.
            if alg[run]["runtime_actual"][0] / 1.0e9 < alg[run]["runtime_requested"][0]:
                print(f"Run {alg.name}/{run} has invalid runtime! Requested: {alg[run]['runtime_requested'][0]}, Actual: {alg[run]['runtime_actual'][0] / 1.0e9 : .2f}")
                continue

            idl, msgs = analyzeRun(alg[run])
        except KeyError as e:
            print(f"Run {alg.name}/{run} has invalid data!")
            continue

        # Print worst average idleness for each run.
        print(f"Run {alg.name}/{run} has worst final average idleness: {np.max(np.mean(idl[:,1:], axis=1))}")
        # if alg.name == "/cumberland_6/MARL" and run == "run_2":
        #     print(f"Skip run {alg.name}/{run}")
        #     continue

        # displayAverageIdleness([idl], ["idleness"], title=f"{alg.name}/{run}", attrition=bool(alg[run]["attrition_times"].size > 0))
        idleness = np.concatenate([idleness, idl[:,1:]], axis=1)
        messages = np.concatenate([messages, msgs], axis=1)
    return idleness, messages

def analyzeFile(filePath, attritionTimes=[]):
    root = zarr.open(filePath, mode="r")
    mapName = "cumberland_6"
    labels = []
    results = []
    msgResults = []
    for algName in root[mapName]:
        if "DTA" in algName:
            print(f"Skipping algorithm {algName}")
            continue
        idleness, messages = analyzeAlg(root[mapName][algName])
        results.append(idleness)
        msgResults.append(messages)
        labels.append(algName)
    
    # Set font sizes.
    # SMALL_SIZE = 16
    # MEDIUM_SIZE = 20
    # BIGGER_SIZE = 24
    # plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
    # plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
    # plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
    # plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    # plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    # plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
    # plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
    # plt.rc('figure', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels

    # Set up the plot.
    fig, axes = plt.subplots(2, 1, sharex=True, figsize=(PLOT_X, PLOT_Y))
    # (axAvgIdleness, axStdIdleness, axMsgs) = axes
    (axAvgIdleness, axStdIdleness) = axes
    fig.supxlabel("Time Elapsed (s)")
    if attritionTimes == []:
        fig.suptitle("Experimental Results (No Attrition)")
    else:
        fig.suptitle("Experimental Results (With Attrition)")
    axes[0].set_title("(a)", loc="left")
    axes[1].set_title("(b)", loc="left")
    # axes[2].set_title("(c)", loc="left")

    # Build the legend.
    # cmap = plt.get_cmap("tab10")
    # handles = []
    # for i in range(len(labels)):
    #     handles.append(mpatches.Patch(color=cmap(i), label=labels[i]))
    # axLegend.clear()
    # axLegend.set_axis_off()
    # axLegend.legend(handles=handles, loc="center")

    
    displayAverageIdleness(axAvgIdleness, results, labels, attritionTimes=attritionTimes)
    displayStdIdleness(axStdIdleness, results, labels, attritionTimes=attritionTimes)
    # displayMessages(axMsgs, msgResults, labels, attritionTimes=attritionTimes)

    axAvgIdleness.legend()
    fig.tight_layout()


    # Save the figure.
    if attritionTimes == []:
        fig.savefig("res_noattrition.png")
    else:
        fig.savefig("res_attrition.png")

PLOT_X = 12
PLOT_Y = 16
def displayAverageIdleness(axis, inputs, labels, attritionTimes=[],
        title="Average Node Idleness vs. Time"
    ):
    for arr, name in zip(inputs, labels):
        axis.plot(np.mean(arr[:,1:], axis=1), label=name)
    # axis.legend()
    # axis.xlabel("Time (s)")
    axis.set(ylabel="Avg. Node Idlnss (s)")
    if len(attritionTimes) > 0:
        # axis.set_title(f"{title} (With Attrition)")
        for t in attritionTimes:
            axis.axvline(t, color="black", ls="--", lw=1.0)
            axis.text(t + 0.1,0,'attrition',rotation=90)
    else:
        # axis.set_title(f"{title} (No Attrition)")
        pass

def displayStdIdleness(axis, inputs, labels, attritionTimes=[]):
    for arr, name in zip(inputs, labels):
        axis.plot(np.std(arr[:,1:], axis=1), label=name)
    # plt.xlabel("Time (s)")
    axis.set(ylabel="Std. Node Idlnss (s)")
    if len(attritionTimes) > 0:
        # axis.set_title("Std. Dev. of Node Idleness vs. Time (With Attrition)")
        for t in attritionTimes:
            axis.axvline(t, color="black", ls="--", lw=1.0)
            axis.text(t + 0.1,0,'attrition',rotation=90)
    else:
        # axis.set_title("Std. Dev. of Node Idleness vs. Time (No Attrition)")
        pass

def displayMessages(axis, inputs, labels, attritionTimes=[],
        title="Messages Broadcast vs. Time"
    ):
    for arr, name in zip(inputs, labels):
        axis.plot(np.mean(arr[:,1:], axis=1), label=name)
    # plt.xlabel("Time (s)")
    axis.set(ylabel="Cum. Messages")
    if len(attritionTimes) > 0:
        # axis.set_title(f"{title} (With Attrition)")
        for t in attritionTimes:
            axis.axvline(t, color="black", ls="--", lw=1.0)
            axis.text(t + 0.1,0,'attrition',rotation=90)
    else:
        # axis.set_title(f"{title} (No Attrition)")
        pass

# analyzeRun(zarr.open("/mnt/c/Users/Anthony/Desktop/results_noattrit3.zarr", "r")["cumberland_6"]["DTAGreedy"]["run_1"])

# %%
# analyzeFile("/home/anthony/papers/aamas2024/sim_results/test_debugging.zarr") # USE IN PAPER
# analyzeFile("/home/anthony/papers/aamas2024/sim_results/marl_attrition.zarr", attritionTimes=[300, 1100]) # USE IN PAPER
# analyzeFile("/home/anthony/papers/aamas2024/sim_results/marl_ateexrx9.zarr", attritionTimes=[300, 1100]) # USE IN PAPER
# analyzeFile("/home/anthony/papers/aamas2024/sim_results/marl_7r3xi5dr.zarr", attritionTimes=[300, 1100]) # USE IN PAPER
# analyzeFile("/home/anthony/papers/aamas2024/sim_results/marl_02x2v2bc.zarr")

# analyzeFile("/home/anthony/papers/aamas2024/sim_results/8f69l6zc_no_attrition.zarr")
# analyzeFile("/home/anthony/papers/aamas2024/sim_results/8f69l6zc_attrition.zarr", attritionTimes=[300, 1100])
# analyzeFile("/home/anthony/papers/aamas2024/sim_results/8f69l6zc_attrition_run2.zarr", attritionTimes=[300, 1100])
# analyzeFile("/home/anthony/papers/aamas2024/sim_results/8f69l6zc_attrition_run3.zarr", attritionTimes=[300, 1100])
# analyzeFile("/home/anthony/papers/aamas2024/sim_results/8f69l6zc_attrition_run6.zarr", attritionTimes=[300, 1100]) #pretty good!
# analyzeFile("/home/anthony/papers/aamas2024/sim_results/n1j1aiut_no_attrition_run1.zarr")
# analyzeFile("/home/anthony/papers/aamas2024/sim_results/n1j1aiut_attrition_run5.zarr", attritionTimes=[300, 1100])

# analyzeFile("/home/anthony/papers/aamas2024/sim_results/n1j1aiut_no_attrition_run2.zarr") # full run of everything
# analyzeFile("/home/anthony/papers/aamas2024/sim_results/n1j1aiut_attrition_run6.zarr", attritionTimes=[300, 1100])  # full run of everything

analyzeFile("/home/anthony/papers/aamas2024/sim_results/rtbr89cz_no_attrition_run1.zarr") # full run of everything
analyzeFile("/home/anthony/papers/aamas2024/sim_results/rtbr89cz_attrition_run2.zarr", attritionTimes=[300, 1100]) # full run of everything
# Out:
# Run /cumberland_6/AHPA/run_1 has worst final average idleness: 85.5160076242
# Run /cumberland_6/AHPA/run_2 has worst final average idleness: 87.15700769215
# Run /cumberland_6/AHPA/run_3 has worst final average idleness: 83.84750760762499
# Run /cumberland_6/CBLS/run_1 has worst final average idleness: 165.24656603767502
# Run /cumberland_6/CBLS/run_2 has worst final average idleness: 156.09657294517498
# Run /cumberland_6/CBLS/run_3 has worst final average idleness: 143.280050136
# Run /cumberland_6/GBS/run_1 has worst final average idleness: 143.67351161632502
# Run /cumberland_6/GBS/run_2 has worst final average idleness: 156.99603860019997
# Run /cumberland_6/GBS/run_3 has worst final average idleness: 124.972534951375
# Run /cumberland_6/MARL/run_1 has worst final average idleness: 129.334566333275
# Run /cumberland_6/MARL/run_2 has worst final average idleness: 153.82157920892502
# Run /cumberland_6/MARL/run_3 has worst final average idleness: 120.57405337129998
# Run /cumberland_6/AHPA/run_1 has worst final average idleness: 209.32906998355003
# Run /cumberland_6/AHPA/run_2 has worst final average idleness: 205.43156942842498
# Run /cumberland_6/AHPA/run_3 has worst final average idleness: 205.20706908965
# Run /cumberland_6/CBLS/run_1 has worst final average idleness: 373.03357079832506
# Run /cumberland_6/CBLS/run_2 has worst final average idleness: 321.614573919275
# Run /cumberland_6/CBLS/run_3 has worst final average idleness: 359.0860669957
# Run /cumberland_6/GBS/run_1 has worst final average idleness: 168.7560804122
# Run /cumberland_6/GBS/run_2 has worst final average idleness: 193.92056995397502
# Run /cumberland_6/GBS/run_3 has worst final average idleness: 180.295561535225
# Run /cumberland_6/MARL/run_1 has worst final average idleness: 232.69605681519997
# Run /cumberland_6/MARL/run_2 has worst final average idleness: 210.6440718678
# Run /cumberland_6/MARL/run_3 has worst final average idleness: 166.491554975425
